# %% [markdown]
# # ContourPlot

# %%
import pandas as pd
kcData = pd.read_csv('./data/kc_house_data.csv',delimiter=',',encoding='utf-8')
kcData
print(kcData.columns)
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
## Create Scatterplott of sqft & price
data = kcData[['sqft_living', 'price']].values.reshape(-1,2)
data = pd.DataFrame(data, columns = ['sqft_living', 'price']) 
print(data)
# Out:
#        sqft_living     price
# 0           1180.0  221900.0
# 1           2570.0  538000.0
# 2            770.0  180000.0
# 3           1960.0  604000.0
# 4           1680.0  510000.0
# ...            ...       ...
# 21608       1530.0  360000.0
# 21609       2310.0  400000.0
# 21610       1020.0  402101.0
# 21611       1600.0  400000.0
# 21612       1020.0  325000.0
#
# [21613 rows x 2 columns]

# %%
xlist=data['sqft_living']
ylist=data['price']
xlist = xlist.loc[:999]
ylist = ylist.loc[:999]
xlist = pd.DataFrame(xlist)
ylist = pd.DataFrame(ylist)
print(xlist.shape)
print(ylist.shape)
# Out:
# (1000, 1)
# (1000, 1)

# %% [markdown]
# ## Contour Plots
# Brauch ich noch nen sinnvollen Anwendungsfall für

# %%
import numpy as np
import matplotlib.pyplot as plt
#xlist = np.linspace(-3.0, 3.0, 100)
#ylist = np.linspace(-3.0, 3.0, 100)
X, Y = np.meshgrid(xlist, ylist)
Z = np.sqrt(X**2 + Y**2)
fig,ax=plt.subplots(1,1)
cp = ax.contourf(X, Y, Z)
fig.colorbar(cp) # Add a colorbar to a plot
ax.set_title('Filled Contours Plot')
#ax.set_xlabel('x (cm)')
ax.set_ylabel('y (cm)')
plt.show()

# %% [markdown]
# ## Scatterplot für KingsCounty

# %%
ax1 = data.plot.scatter(x='sqft_living',
                      y='price',
                      c='DarkBlue')

# %% [markdown]
# Das Scatterplott ermöglicht keinen konkreten Einblick in einen möglichen Trend

# %% [markdown]
# ## HexagonnalBinning für KingsCounty

# %%
ax1 = data.plot.hexbin(x='sqft_living',
                      y='price',
                       gridsize=(15,15))

# %% [markdown]
# # Tutorial zur Erklärung
# [link1](https://www.meccanismocomplesso.org/en/hexagonal-binning-a-new-method-of-visualization-for-data-analysis/)
#
# Wenn mehrer bzw einfach zuviele Variablen  in einem Scatterplot dargesellt werden, wird es schnell unübersichtlich. Mit der weiteren Variable.
#
# Bspw:<br<
# Das ist der Trend den man versucht herauszufinden:
# <img src="https://github.com/JHC90/Basic-DataScience-Skills/blob/master/imgs/hexbins-scatterplot2.jpg?raw=true" alt="MedianOdd">
#
# jedoch gibt es mehererDatenpunkt die den Trend nicht auf den ersten Blick ersichtlich machen:
# <img src="https://github.com/JHC90/Basic-DataScience-Skills/blob/master/imgs/hexbins-scatterplot.jpg?raw=true" alt="MedianOdd">
#
# letztlich sieht die Summe aus den oberen beiden Bildern etwa so aus:
# <img src="https://github.com/JHC90/Basic-DataScience-Skills/blob/master/imgs/scatterplot-real.jpg?raw=true" alt="MedianOdd">
#
# Mittels des Density Plot kann der Trend dennoch trotz des gesammten Rauschens herausgefiltert werden:
# <img src="https://github.com/JHC90/Basic-DataScience-Skills/blob/master/imgs/hexbins-hexagonal.jpg?raw=true![image.png](attachment:image.png)" alt="MedianOdd">
#
# ## Zusammenfassung
# mittels Hex-Binning kann somit in einem Datensatz mit erhöhtem Rauschen dennoch der zugrundeliegende Trend daregestellt werden
