# %% [markdown]
# <a href="https://datamics.com/de/courses/"><img src=../DATA/bg_datamics_top.png></a>
#
# <em text-align:center>© Datamics</em>
# # TensorFlow Klassifikation

# %% [markdown]
# ## Daten
#
# https://archive.ics.uci.edu/ml/datasets/pima+indians+diabetes
#
# 1. Titel: Pima Indians Diabetes Database
#
# 2. Quelle:
#    (a) Ursprünglicher Besitzer: National Institute of Diabetes and Digestive and
#                                 Kidney Diseases
#     (b) Datenbankspender: Vincent Sigillito (vgs@aplcen.apl.jhu.edu)
#                           Research Center, RMI Group Leader
#                           Applied Physics Laboratory
#                           The Johns Hopkins University
#                           Johns Hopkins Road
#                           Laurel, MD 20707
#                           (301) 953-6231
#    (c) Daten erhalten: 9 May 1990
#
# 3. Vorherige Verwendung:
#     1. Smith,~J.~W., Everhart,~J.~E., Dickson,~W.~C., Knowler,~W.~C., \&
#        Johannes,~R.~S. (1988). Mit Hilfe des ADAP Lernalgorithmus den beginn von Diabetes zu prognostizieren.
#       {\it Tagungsband des Symposiums für Computeranwendungen und medizinische Versorgung} (pp. 261--265).  IEEE
#        Computer Society Press.
#
#
# Die diagnostische, binär bewertete Variable untersuchte, ob der Patient Anzeichen von Diabetes nach den Kriterien der Weltgesundheitsorganisation zeigt (d.h. ob der 2-stündige Plasmaglukosespiegel bei jeder Untersuchung oder während der medizinischen Routineuntersuchung mindestens 200 mg/dl betrug).
#
#
#        Ergebnisse: Ihr ADAP-Algorithmus macht eine reale Vorhersage zwischen 0 und 1. Diese wurde mit einem Cutoff von 0,448 in eine binäre Entscheidung umgewandelt. Unter Verwendung von 576 Trainingsinstanzen betrug die Sensitivität und Spezifität ihres Algorithmus bei den restlichen 192 Instanzen 76%.
#
# 4. Relevante Information:
#
# Bei der Auswahl dieser Instanzen aus einer größeren Datenbank gab es mehrere Einschränkungen. Insbesondere sind alle Patienten hier Frauen, die mindestens 21 Jahre alt sind. ADAP ist eine adaptive Lernroutine, die digitale Analoga von perzeptronähnlichen Geräten erzeugt und ausführt. Es ist ein einzigartiger Algorithmus. Mehr Details sind in der Veröffentlichung zu finden.
#
# 5. Anzahl der Instanzen: 768
#
# 6. Anzahl der Attribute:   8 Plus Klasse
#
# * Anzahl der Schwangerschaften
# * Plasmaglukosekonzentration nach 2 Stunden im oralen Glukosetoleranztest
# * Diastolischer Blutdruck (mm Hg)
# * Trizeps Hautfaltendicke (mm)
# * 2-Stunden-Serum-Insulin (mu U/ml)
# * Body-Mass-Index (Gewicht in kg/(Größe in m)^2)
# * Diabetes-Stammbaumfunktion
#
#
#     7. Für jedes Attribut: (Numerische Werte)
#        1. Anzahl der Schwangerschaften
#        2. Plasmaglukosekonzentration nach 2 Stunden im oralen Glukosetoleranztest
#        3. Diastolischer Blutdruck (mm Hg)
#        4. Trizeps Hautfaltendicke (mm)
#        5. 2-Stunden-Serum-Insulin (mu U/ml)
#        6. Body-Mass-Index (Gewicht in kg/(Größe in m)^2)
#        7. Diabetes-Stammbaumfunktion
#        8. Alter (Jahre)
#        9. Klassenvariable (0 oder 1)
#
# 8. Fehlende Attributwerte: Ja
#
# 9. Klassen Distribution: (Klassenvariable 1 wird als "Positiv auf Diabetis getestet" interpretiert)
#
#
#    Klassenvariable   Anzahl der Fälle
#            0            500
#            1            268
#
# 10. Kurze statistische Auswertung:
#
#         Attributwert:    Mittelwert:   Standardabweichung:
#         1.                     3.8     3.4
#         2.                   120.9    32.0
#         3.                    69.1    19.4
#         4.                    20.5    16.0
#         5.                    79.8   115.2
#         6.                    32.0     7.9
#         7.                     0.5     0.3
#         8.                    33.2    11.8

# %%
import pandas as pd

# %%
diabetes = pd.read_csv('pima-indians-diabetes.csv')

# %%
diabetes.info() # => grup = object = Kategorisch
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Number_pregnant        768 non-null    int64
#  1   Glucose_concentration  768 non-null    float64
#  2   Blood_pressure         768 non-null    float64
#  3   Triceps                768 non-null    float64
#  4   Insulin                768 non-null    float64
#  5   BMI                    768 non-null    float64
#  6   Pedigree               768 non-null    float64
#  7   Age                    768 non-null    int64
#  8   Class                  768 non-null    int64
#  9   Group                  768 non-null    object
# dtypes: float64(6), int64(3), object(1)
# memory usage: 60.1+ KB

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0                6               0.743719        0.590164  0.353535  0.000000
# 1                1               0.427136        0.540984  0.292929  0.000000
# 2                8               0.919598        0.524590  0.000000  0.000000
# 3                1               0.447236        0.540984  0.232323  0.111111
# 4                0               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %% [markdown]
# ### Daten Bereinigen
# hierbei wollen wir die Daten Normalisieren

# %%
# Auswahl der Spalten für die Normaisierung, das geht nur mit numerischen Werten
cols_to_norm = ['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
       'Insulin', 'BMI', 'Pedigree']

# %%
# hier wird die normalisierung durchgeführt mit einer 
diabetes[cols_to_norm] = diabetes[cols_to_norm].apply(lambda x: (x - x.min()) / (x.max() - x.min()))

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %% [markdown]
# ### Feature Spalten

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
# Out:
# C:\Users\1810837475\.conda\envs\tensorflow_cpu\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\1810837475\.conda\envs\tensorflow_cpu\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\1810837475\.conda\envs\tensorflow_cpu\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\1810837475\.conda\envs\tensorflow_cpu\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\1810837475\.conda\envs\tensorflow_cpu\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\1810837475\.conda\envs\tensorflow_cpu\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING:tensorflow:From C:\Users\1810837475\.conda\envs\tensorflow_cpu\lib\site-packages\tensorflow\python\compat\v2_compat.py:61: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# C:\Users\1810837475\.conda\envs\tensorflow_cpu\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\1810837475\.conda\envs\tensorflow_cpu\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\1810837475\.conda\envs\tensorflow_cpu\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\1810837475\.conda\envs\tensorflow_cpu\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\1810837475\.conda\envs\tensorflow_cpu\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\1810837475\.conda\envs\tensorflow_cpu\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# ### Kontinuierliche Features
#
# * Anzahl der Schwangerschaften
# * Plasmaglukosekonzentration nach 2 Stunden im oralen Glukosetoleranztest
# * Diastolischer Blutdruck (mm Hg)
# * Trizeps Hautfaltendicke (mm)
# * 2-Stunden-Serum-Insulin (mu U/ml)
# * Body-Mass-Index (Gewicht in kg/(Größe in m)^2)
# * Diabetes Stammbaumfunktion

# %%
num_preg = tf.feature_column.numeric_column('Number_pregnant')
plasma_gluc = tf.feature_column.numeric_column('Glucose_concentration')
dias_press = tf.feature_column.numeric_column('Blood_pressure')
tricep = tf.feature_column.numeric_column('Triceps')
insulin = tf.feature_column.numeric_column('Insulin')
bmi = tf.feature_column.numeric_column('BMI')
diabetes_pedigree = tf.feature_column.numeric_column('Pedigree')
age = tf.feature_column.numeric_column('Age')

# %% [markdown]
# ### Kategorische Features

# %% [markdown]
# Wenn du die Menge aller möglichen Features einer Spalte kennst und es nur wenige davon gibt, kannst du `categorical_column_with_vocabulary_list` verwenden. Wenn du die Menge der möglichen Features nicht kennst, kannst du `categorical_column_with_hash_bucket` verwenden.

# %%
#diabetes['Group'].unique()
assigned_group = tf.feature_column.categorical_column_with_vocabulary_list('Group',['A','B','C','D'])
# Alternative mit Hashbucket ...die  besagt das das vom DS geschätzet maximal zahl ist
# assigned_group = tf.feature_column.categorical_column_with_hash_bucket('Group', hash_bucket_size=10)

# %% [markdown]
# ### Kontinuierliche zu kategorischen Variablen umwandeln

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
diabetes['Age'].hist(bins=20)

# %%
age_buckets = tf.feature_column.bucketized_column(age, boundaries=[20,30,40,50,60,70,80])

# %% [markdown]
# ### Nun fügen wir sie zusammen

# %%
feat_cols = [num_preg ,plasma_gluc,dias_press ,tricep ,insulin,bmi,diabetes_pedigree ,assigned_group, age_buckets]

# %% [markdown]
# ### Train Test Split

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Number_pregnant        768 non-null    float64
#  1   Glucose_concentration  768 non-null    float64
#  2   Blood_pressure         768 non-null    float64
#  3   Triceps                768 non-null    float64
#  4   Insulin                768 non-null    float64
#  5   BMI                    768 non-null    float64
#  6   Pedigree               768 non-null    float64
#  7   Age                    768 non-null    int64
#  8   Class                  768 non-null    int64
#  9   Group                  768 non-null    object
# dtypes: float64(7), int64(2), object(1)
# memory usage: 60.1+ KB

# %%
x_data = diabetes.drop('Class',axis=1)

# %%
labels = diabetes['Class']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x_data,labels,test_size=0.33, random_state=101)

# %% [markdown]
# ### Input Funktion

# %%
# Daten für Training / check dann in dem Schritt in welchem man das Modell trainiert, nicht im Modell erstellen
# Im training soll der Shuffle auf true sein
input_func = tf.estimator.inputs.pandas_input_fn(
    x=X_train,
    y=y_train,
    batch_size=10,
    num_epochs=1000,
    shuffle=True)

# %% [markdown]
# ### Das Modell erstellen // Logistic Regression
# es geht um eine binäre Klassifikation mit dem Kerngedanken ob jemand Daibetis hat oder eben nicht => o oder 1

# %%
model = tf.estimator.LinearClassifier(feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\181083~1\AppData\Local\Temp\tmpglg9zthp
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\181083~1\\AppData\\Local\\Temp\\tmpglg9zthp', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x000001E3F8C019C8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
# hier wird das Modell tatsählich trainiert
model.train(input_fn=input_func,steps=1000)
# Out:
# WARNING:tensorflow:From C:\Users\1810837475\.conda\envs\tensorflow_cpu\lib\site-packages\tensorflow\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From C:\Users\1810837475\.conda\envs\tensorflow_cpu\lib\site-packages\tensorflow_estimator\python\estimator\inputs\queues\feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From C:\Users\1810837475\.conda\envs\tensorflow_cpu\lib\site-packages\tensorflow_estimator\python\estimator\inputs\queues\feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Entity <bound method LinearModel.call of <tensorflow.python.feature_column.feature_column_v2.LinearModel object at 0x000001E3F8C82848>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LinearModel.call of <tensorflow.python.feature_column.feature_column_v2.LinearModel object at 0x000001E3F8C82848>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method LinearModel.call of <tensorflow.python.feature_column.feature_column_v2.LinearModel object at 0x000001E3F8C82848>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LinearModel.call of <tensorflow.python.feature_column.feature_column_v2.LinearModel object at 0x000001E3F8C82848>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method _LinearModelLayer.call of <tensorflow.python.feature_column.feature_column_v2._LinearModelLayer object at 0x000001E3F8CACBC8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method _LinearModelLayer.call of <tensorflow.python.feature_column.feature_column_v2._LinearModelLayer object at 0x000001E3F8CACBC8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method _LinearModelLayer.call of <tensorflow.python.feature_column.feature_column_v2._LinearModelLayer object at 0x000001E3F8CACBC8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method _LinearModelLayer.call of <tensorflow.python.feature_column.feature_column_v2._LinearModelLayer object at 0x000001E3F8CACBC8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:From C:\Users\1810837475\.conda\envs\tensorflow_cpu\lib\site-packages\tensorflow\python\ops\sparse_ops.py:1719: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\1810837475\.conda\envs\tensorflow_cpu\lib\site-packages\tensorflow_estimator\python\estimator\canned\linear.py:308: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From C:\Users\1810837475\.conda\envs\tensorflow_cpu\lib\site-packages\tensorflow\python\training\monitored_session.py:875: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Saving checkpoints for 0 into C:\Users\181083~1\AppData\Local\Temp\tmpglg9zthp\model.ckpt.
# INFO:tensorflow:loss = 6.931472, step = 1
# INFO:tensorflow:global_step/sec: 168.201
# INFO:tensorflow:loss = 6.8468933, step = 101 (0.598 sec)
# INFO:tensorflow:global_step/sec: 243.902
# INFO:tensorflow:loss = 4.293378, step = 201 (0.417 sec)
# INFO:tensorflow:global_step/sec: 235.294
# INFO:tensorflow:loss = 5.6647935, step = 301 (0.420 sec)
# INFO:tensorflow:global_step/sec: 238.096
# INFO:tensorflow:loss = 5.4981194, step = 401 (0.422 sec)
# INFO:tensorflow:global_step/sec: 230.414
# INFO:tensorflow:loss = 5.560321, step = 501 (0.436 sec)
# INFO:tensorflow:global_step/sec: 236.719
# INFO:tensorflow:loss = 4.0796247, step = 601 (0.418 sec)
# INFO:tensorflow:global_step/sec: 237.017
# INFO:tensorflow:loss = 4.3720255, step = 701 (0.428 sec)
# INFO:tensorflow:global_step/sec: 236.289
# INFO:tensorflow:loss = 5.208596, step = 801 (0.417 sec)
# INFO:tensorflow:global_step/sec: 247.181
# INFO:tensorflow:loss = 4.7517605, step = 901 (0.410 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\181083~1\AppData\Local\Temp\tmpglg9zthp\model.ckpt.
# INFO:tensorflow:Loss for final step: 7.2631116.

# %%
# Hilfreicher Link:
# https://stackoverflow.com/questions/44664285/what-are-the-contraints-for-tensorflow-scope-names

# %% [markdown]
# ## Evaluation

# %%
# Input function für die Evaluierung => daher auch die TestDaten
eval_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      y=y_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
# Erstellen der vorhersagen => 
results = model.evaluate(eval_input_func)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Entity <bound method LinearModel.call of <tensorflow.python.feature_column.feature_column_v2.LinearModel object at 0x000001E3FB1F9FC8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LinearModel.call of <tensorflow.python.feature_column.feature_column_v2.LinearModel object at 0x000001E3FB1F9FC8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method LinearModel.call of <tensorflow.python.feature_column.feature_column_v2.LinearModel object at 0x000001E3FB1F9FC8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LinearModel.call of <tensorflow.python.feature_column.feature_column_v2.LinearModel object at 0x000001E3FB1F9FC8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method _LinearModelLayer.call of <tensorflow.python.feature_column.feature_column_v2._LinearModelLayer object at 0x000001E3FC462708>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method _LinearModelLayer.call of <tensorflow.python.feature_column.feature_column_v2._LinearModelLayer object at 0x000001E3FC462708>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method _LinearModelLayer.call of <tensorflow.python.feature_column.feature_column_v2._LinearModelLayer object at 0x000001E3FC462708>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method _LinearModelLayer.call of <tensorflow.python.feature_column.feature_column_v2._LinearModelLayer object at 0x000001E3FC462708>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:From C:\Users\1810837475\.conda\envs\tensorflow_cpu\lib\site-packages\tensorflow\python\ops\metrics_impl.py:2027: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-27T10:39:47Z
# INFO:tensorflow:Graph was finalized.
# WARNING:tensorflow:From C:\Users\1810837475\.conda\envs\tensorflow_cpu\lib\site-packages\tensorflow\python\training\saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from C:\Users\181083~1\AppData\Local\Temp\tmpglg9zthp\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2020-04-27-10:39:48
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.72834647, accuracy_baseline = 0.65748036, auc = 0.78670245, auc_precision_recall = 0.63040775, average_loss = 0.5323765, global_step = 1000, label/mean = 0.34251967, loss = 5.200909, precision = 0.6125, prediction/mean = 0.37170228, recall = 0.5632184
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: C:\Users\181083~1\AppData\Local\Temp\tmpglg9zthp\model.ckpt-1000

# %%
results #
# Out:
# {'accuracy': 0.72834647,
#  'accuracy_baseline': 0.65748036,
#  'auc': 0.78670245,
#  'auc_precision_recall': 0.63040775,
#  'average_loss': 0.5323765,
#  'label/mean': 0.34251967,
#  'loss': 5.200909,
#  'precision': 0.6125,
#  'prediction/mean': 0.37170228,
#  'recall': 0.5632184,
#  'global_step': 1000}

# %% [markdown]
# <a name="Anker"></a>
# **Interpretation Results Model Evaluation**<br>
# wir haben eine Accuracy von 72%, das ist so lala bei den Testdaten

# %% [markdown]
# ## Vorhersagen

# %%
pred_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
# Predictions ist ein Generator 
predictions = model.predict(pred_input_func)

# %%
list(predictions)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Entity <bound method LinearModel.call of <tensorflow.python.feature_column.feature_column_v2.LinearModel object at 0x000001E3FC8DFD08>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LinearModel.call of <tensorflow.python.feature_column.feature_column_v2.LinearModel object at 0x000001E3FC8DFD08>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method LinearModel.call of <tensorflow.python.feature_column.feature_column_v2.LinearModel object at 0x000001E3FC8DFD08>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LinearModel.call of <tensorflow.python.feature_column.feature_column_v2.LinearModel object at 0x000001E3FC8DFD08>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method _LinearModelLayer.call of <tensorflow.python.feature_column.feature_column_v2._LinearModelLayer object at 0x000001E3FC8ED1C8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method _LinearModelLayer.call of <tensorflow.python.feature_column.feature_column_v2._LinearModelLayer object at 0x000001E3FC8ED1C8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method _LinearModelLayer.call of <tensorflow.python.feature_column.feature_column_v2._LinearModelLayer object at 0x000001E3FC8ED1C8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method _LinearModelLayer.call of <tensorflow.python.feature_column.feature_column_v2._LinearModelLayer object at 0x000001E3FC8ED1C8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\181083~1\AppData\Local\Temp\tmpglg9zthp\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [{'logits': array([0.11312699], dtype=float32),
#   'logistic': array([0.52825165], dtype=float32),
#   'probabilities': array([0.47174835, 0.5282516 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.51490474], dtype=float32),
#   'logistic': array([0.6259556], dtype=float32),
#   'probabilities': array([0.37404445, 0.6259555 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.39873457], dtype=float32),
#   'logistic': array([0.40161642], dtype=float32),
#   'probabilities': array([0.5983836, 0.4016164], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.7094346], dtype=float32),
#   'logistic': array([0.32972378], dtype=float32),
#   'probabilities': array([0.6702762 , 0.32972378], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7817765], dtype=float32),
#   'logistic': array([0.14408392], dtype=float32),
#   'probabilities': array([0.85591614, 0.14408392], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.8727813], dtype=float32),
#   'logistic': array([0.7053241], dtype=float32),
#   'probabilities': array([0.29467592, 0.7053241 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.37444746], dtype=float32),
#   'logistic': array([0.5925332], dtype=float32),
#   'probabilities': array([0.4074668, 0.5925332], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.63309747], dtype=float32),
#   'logistic': array([0.34680855], dtype=float32),
#   'probabilities': array([0.6531915 , 0.34680852], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1581848], dtype=float32),
#   'logistic': array([0.2389973], dtype=float32),
#   'probabilities': array([0.7610028, 0.2389973], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.154869], dtype=float32),
#   'logistic': array([0.23960085], dtype=float32),
#   'probabilities': array([0.76039916, 0.23960088], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8911438], dtype=float32),
#   'logistic': array([0.1311141], dtype=float32),
#   'probabilities': array([0.8688859 , 0.13111411], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7340071], dtype=float32),
#   'logistic': array([0.15007576], dtype=float32),
#   'probabilities': array([0.84992427, 0.15007575], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.8291391], dtype=float32),
#   'logistic': array([0.3038271], dtype=float32),
#   'probabilities': array([0.69617283, 0.30382714], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.30952275], dtype=float32),
#   'logistic': array([0.57676876], dtype=float32),
#   'probabilities': array([0.4232312 , 0.57676876], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5637786], dtype=float32),
#   'logistic': array([0.17310509], dtype=float32),
#   'probabilities': array([0.8268949, 0.1731051], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.6239497], dtype=float32),
#   'logistic': array([0.3488837], dtype=float32),
#   'probabilities': array([0.6511164, 0.3488837], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.42649257], dtype=float32),
#   'logistic': array([0.3949642], dtype=float32),
#   'probabilities': array([0.60503584, 0.3949642 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9029717], dtype=float32),
#   'logistic': array([0.12977251], dtype=float32),
#   'probabilities': array([0.87022746, 0.1297725 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.5230001], dtype=float32),
#   'logistic': array([0.372151], dtype=float32),
#   'probabilities': array([0.62784904, 0.372151  ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8252794], dtype=float32),
#   'logistic': array([0.1388016], dtype=float32),
#   'probabilities': array([0.86119837, 0.13880159], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2978104], dtype=float32),
#   'logistic': array([0.21453372], dtype=float32),
#   'probabilities': array([0.7854662 , 0.21453373], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.8572179], dtype=float32),
#   'logistic': array([0.29792094], dtype=float32),
#   'probabilities': array([0.70207906, 0.2979209 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.6791744], dtype=float32),
#   'logistic': array([0.6635544], dtype=float32),
#   'probabilities': array([0.33644557, 0.6635544 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3225694], dtype=float32),
#   'logistic': array([0.21039113], dtype=float32),
#   'probabilities': array([0.7896089 , 0.21039113], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.458233], dtype=float32),
#   'logistic': array([0.18873775], dtype=float32),
#   'probabilities': array([0.8112623 , 0.18873775], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.2903848], dtype=float32),
#   'logistic': array([0.78421235], dtype=float32),
#   'probabilities': array([0.21578771, 0.78421235], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5317546], dtype=float32),
#   'logistic': array([0.17773712], dtype=float32),
#   'probabilities': array([0.82226294, 0.17773712], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.7590795], dtype=float32),
#   'logistic': array([0.31884617], dtype=float32),
#   'probabilities': array([0.68115383, 0.31884614], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.1694555], dtype=float32),
#   'logistic': array([0.10252712], dtype=float32),
#   'probabilities': array([0.89747286, 0.10252712], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.36255324], dtype=float32),
#   'logistic': array([0.5896583], dtype=float32),
#   'probabilities': array([0.41034162, 0.5896583 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([2.835283], dtype=float32),
#   'logistic': array([0.94455296], dtype=float32),
#   'probabilities': array([0.05544706, 0.94455296], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.41780317], dtype=float32),
#   'logistic': array([0.39704257], dtype=float32),
#   'probabilities': array([0.6029574 , 0.39704254], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.768211], dtype=float32),
#   'logistic': array([0.31686628], dtype=float32),
#   'probabilities': array([0.6831338 , 0.31686625], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.2316482], dtype=float32),
#   'logistic': array([0.55765444], dtype=float32),
#   'probabilities': array([0.44234556, 0.5576545 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.051162], dtype=float32),
#   'logistic': array([0.25900203], dtype=float32),
#   'probabilities': array([0.74099797, 0.25900203], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.4032523], dtype=float32),
#   'logistic': array([0.4005312], dtype=float32),
#   'probabilities': array([0.5994688, 0.4005312], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.02680719], dtype=float32),
#   'logistic': array([0.5067014], dtype=float32),
#   'probabilities': array([0.49329862, 0.5067014 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.51143444], dtype=float32),
#   'logistic': array([0.6251427], dtype=float32),
#   'probabilities': array([0.3748573 , 0.62514263], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.1743295], dtype=float32),
#   'logistic': array([0.7639267], dtype=float32),
#   'probabilities': array([0.23607329, 0.7639267 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.7280985], dtype=float32),
#   'logistic': array([0.32561213], dtype=float32),
#   'probabilities': array([0.6743879 , 0.32561213], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5113273], dtype=float32),
#   'logistic': array([0.18074214], dtype=float32),
#   'probabilities': array([0.81925786, 0.18074219], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.19221973], dtype=float32),
#   'logistic': array([0.54790753], dtype=float32),
#   'probabilities': array([0.45209253, 0.54790753], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6532736], dtype=float32),
#   'logistic': array([0.160667], dtype=float32),
#   'probabilities': array([0.839333  , 0.16066702], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.07201874], dtype=float32),
#   'logistic': array([0.5179969], dtype=float32),
#   'probabilities': array([0.4820031, 0.5179969], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7405813], dtype=float32),
#   'logistic': array([0.14923912], dtype=float32),
#   'probabilities': array([0.8507609 , 0.14923912], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.1298103], dtype=float32),
#   'logistic': array([0.106233], dtype=float32),
#   'probabilities': array([0.89376694, 0.10623299], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.4085722], dtype=float32),
#   'logistic': array([0.60074544], dtype=float32),
#   'probabilities': array([0.39925453, 0.6007455 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4955677], dtype=float32),
#   'logistic': array([0.1830875], dtype=float32),
#   'probabilities': array([0.8169125 , 0.18308751], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3142798], dtype=float32),
#   'logistic': array([0.21177156], dtype=float32),
#   'probabilities': array([0.78822845, 0.21177158], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.0008023], dtype=float32),
#   'logistic': array([0.11911871], dtype=float32),
#   'probabilities': array([0.8808813 , 0.11911872], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6021657], dtype=float32),
#   'logistic': array([0.16767916], dtype=float32),
#   'probabilities': array([0.8323208 , 0.16767913], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.081779], dtype=float32),
#   'logistic': array([0.25316954], dtype=float32),
#   'probabilities': array([0.7468305 , 0.25316954], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0738828], dtype=float32),
#   'logistic': array([0.2546654], dtype=float32),
#   'probabilities': array([0.74533457, 0.25466537], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.5460306], dtype=float32),
#   'logistic': array([0.36678585], dtype=float32),
#   'probabilities': array([0.6332142 , 0.36678582], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8145072], dtype=float32),
#   'logistic': array([0.14009422], dtype=float32),
#   'probabilities': array([0.8599057 , 0.14009427], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.280088], dtype=float32),
#   'logistic': array([0.21753529], dtype=float32),
#   'probabilities': array([0.78246474, 0.21753524], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3277111], dtype=float32),
#   'logistic': array([0.20953825], dtype=float32),
#   'probabilities': array([0.7904618 , 0.20953822], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3163756], dtype=float32),
#   'logistic': array([0.21142194], dtype=float32),
#   'probabilities': array([0.7885781 , 0.21142194], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.02941859], dtype=float32),
#   'logistic': array([0.5073541], dtype=float32),
#   'probabilities': array([0.49264583, 0.5073541 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6395829], dtype=float32),
#   'logistic': array([0.16252184], dtype=float32),
#   'probabilities': array([0.8374782 , 0.16252184], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.190453], dtype=float32),
#   'logistic': array([0.23317793], dtype=float32),
#   'probabilities': array([0.7668221 , 0.23317792], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.60028887], dtype=float32),
#   'logistic': array([0.6457224], dtype=float32),
#   'probabilities': array([0.3542776, 0.6457224], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.5463394], dtype=float32),
#   'logistic': array([0.6332859], dtype=float32),
#   'probabilities': array([0.36671412, 0.6332859 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.08524847], dtype=float32),
#   'logistic': array([0.52129924], dtype=float32),
#   'probabilities': array([0.4787008 , 0.52129924], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.57588], dtype=float32),
#   'logistic': array([0.35988116], dtype=float32),
#   'probabilities': array([0.6401189, 0.3598812], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.01180661], dtype=float32),
#   'logistic': array([0.49704838], dtype=float32),
#   'probabilities': array([0.5029516, 0.4970484], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4943901], dtype=float32),
#   'logistic': array([0.18326369], dtype=float32),
#   'probabilities': array([0.81673634, 0.18326372], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3172975], dtype=float32),
#   'logistic': array([0.21126825], dtype=float32),
#   'probabilities': array([0.7887317 , 0.21126826], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7348506], dtype=float32),
#   'logistic': array([0.14996818], dtype=float32),
#   'probabilities': array([0.85003185, 0.14996818], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.830177], dtype=float32),
#   'logistic': array([0.1382172], dtype=float32),
#   'probabilities': array([0.86178285, 0.13821721], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.42672312], dtype=float32),
#   'logistic': array([0.6050909], dtype=float32),
#   'probabilities': array([0.39490908, 0.6050909 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1097162], dtype=float32),
#   'logistic': array([0.24792379], dtype=float32),
#   'probabilities': array([0.75207615, 0.24792379], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.3043126], dtype=float32),
#   'logistic': array([0.42450356], dtype=float32),
#   'probabilities': array([0.57549644, 0.42450356], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.34452176], dtype=float32),
#   'logistic': array([0.58528847], dtype=float32),
#   'probabilities': array([0.4147115 , 0.58528847], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.89325285], dtype=float32),
#   'logistic': array([0.290439], dtype=float32),
#   'probabilities': array([0.709561, 0.290439], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.54117334], dtype=float32),
#   'logistic': array([0.6320853], dtype=float32),
#   'probabilities': array([0.36791465, 0.6320853 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9536294], dtype=float32),
#   'logistic': array([0.12415814], dtype=float32),
#   'probabilities': array([0.8758418 , 0.12415815], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.38195038], dtype=float32),
#   'logistic': array([0.5943434], dtype=float32),
#   'probabilities': array([0.40565658, 0.5943434 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9322617], dtype=float32),
#   'logistic': array([0.12650046], dtype=float32),
#   'probabilities': array([0.8734995 , 0.12650046], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.24394], dtype=float32),
#   'logistic': array([0.5606844], dtype=float32),
#   'probabilities': array([0.43931565, 0.5606844 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.6047046], dtype=float32),
#   'logistic': array([0.3532681], dtype=float32),
#   'probabilities': array([0.6467319, 0.3532681], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5544007], dtype=float32),
#   'logistic': array([0.17445159], dtype=float32),
#   'probabilities': array([0.8255484 , 0.17445157], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.2716676], dtype=float32),
#   'logistic': array([0.56750226], dtype=float32),
#   'probabilities': array([0.43249777, 0.56750226], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.3550123], dtype=float32),
#   'logistic': array([0.5878325], dtype=float32),
#   'probabilities': array([0.4121675, 0.5878325], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.23011231], dtype=float32),
#   'logistic': array([0.55727553], dtype=float32),
#   'probabilities': array([0.44272447, 0.5572756 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6138644], dtype=float32),
#   'logistic': array([0.16605276], dtype=float32),
#   'probabilities': array([0.8339472 , 0.16605277], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.57654524], dtype=float32),
#   'logistic': array([0.35972795], dtype=float32),
#   'probabilities': array([0.6402721 , 0.35972792], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7355758], dtype=float32),
#   'logistic': array([0.14987573], dtype=float32),
#   'probabilities': array([0.85012424, 0.14987576], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.9810436], dtype=float32),
#   'logistic': array([0.72731525], dtype=float32),
#   'probabilities': array([0.27268475, 0.72731525], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.5687664], dtype=float32),
#   'logistic': array([0.82760763], dtype=float32),
#   'probabilities': array([0.17239232, 0.82760763], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.49539256], dtype=float32),
#   'logistic': array([0.6213759], dtype=float32),
#   'probabilities': array([0.37862405, 0.621376  ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3340185], dtype=float32),
#   'logistic': array([0.20849547], dtype=float32),
#   'probabilities': array([0.7915046 , 0.20849545], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.23233265], dtype=float32),
#   'logistic': array([0.4421767], dtype=float32),
#   'probabilities': array([0.5578233 , 0.44217673], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.5461094], dtype=float32),
#   'logistic': array([0.36676753], dtype=float32),
#   'probabilities': array([0.6332325 , 0.36676756], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.07794249], dtype=float32),
#   'logistic': array([0.48052424], dtype=float32),
#   'probabilities': array([0.51947576, 0.4805242 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.6521738], dtype=float32),
#   'logistic': array([0.34249985], dtype=float32),
#   'probabilities': array([0.65750015, 0.34249982], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.19822532], dtype=float32),
#   'logistic': array([0.4506053], dtype=float32),
#   'probabilities': array([0.54939467, 0.4506053 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6188155], dtype=float32),
#   'logistic': array([0.16536829], dtype=float32),
#   'probabilities': array([0.83463174, 0.16536829], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.24686003], dtype=float32),
#   'logistic': array([0.5614035], dtype=float32),
#   'probabilities': array([0.43859652, 0.5614035 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.23827708], dtype=float32),
#   'logistic': array([0.559289], dtype=float32),
#   'probabilities': array([0.44071093, 0.559289  ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1879876], dtype=float32),
#   'logistic': array([0.23361903], dtype=float32),
#   'probabilities': array([0.76638097, 0.23361905], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4662275], dtype=float32),
#   'logistic': array([0.18751666], dtype=float32),
#   'probabilities': array([0.8124833 , 0.18751669], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5716164], dtype=float32),
#   'logistic': array([0.17198607], dtype=float32),
#   'probabilities': array([0.8280139 , 0.17198607], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.9460185], dtype=float32),
#   'logistic': array([0.27968624], dtype=float32),
#   'probabilities': array([0.7203137 , 0.27968624], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.5194869], dtype=float32),
#   'logistic': array([0.37297222], dtype=float32),
#   'probabilities': array([0.62702775, 0.37297222], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7716343], dtype=float32),
#   'logistic': array([0.14533919], dtype=float32),
#   'probabilities': array([0.8546608, 0.1453392], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.7789804], dtype=float32),
#   'logistic': array([0.3145397], dtype=float32),
#   'probabilities': array([0.6854603, 0.3145397], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2062751], dtype=float32),
#   'logistic': array([0.23036078], dtype=float32),
#   'probabilities': array([0.7696392 , 0.23036079], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.24236], dtype=float32),
#   'logistic': array([0.09601051], dtype=float32),
#   'probabilities': array([0.90398943, 0.09601051], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9429175], dtype=float32),
#   'logistic': array([0.12532769], dtype=float32),
#   'probabilities': array([0.87467235, 0.12532769], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.0760589], dtype=float32),
#   'logistic': array([0.74574745], dtype=float32),
#   'probabilities': array([0.25425255, 0.74574745], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5364811], dtype=float32),
#   'logistic': array([0.1770474], dtype=float32),
#   'probabilities': array([0.8229526, 0.1770474], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8189328], dtype=float32),
#   'logistic': array([0.13956198], dtype=float32),
#   'probabilities': array([0.860438  , 0.13956198], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7855041], dtype=float32),
#   'logistic': array([0.14362484], dtype=float32),
#   'probabilities': array([0.8563752 , 0.14362483], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.01758516], dtype=float32),
#   'logistic': array([0.5043962], dtype=float32),
#   'probabilities': array([0.49560386, 0.5043962 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.20922035], dtype=float32),
#   'logistic': array([0.4478849], dtype=float32),
#   'probabilities': array([0.55211514, 0.4478849 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1476312], dtype=float32),
#   'logistic': array([0.24092203], dtype=float32),
#   'probabilities': array([0.75907797, 0.240922  ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.2838713], dtype=float32),
#   'logistic': array([0.42950493], dtype=float32),
#   'probabilities': array([0.57049507, 0.42950493], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4084842], dtype=float32),
#   'logistic': array([0.19647324], dtype=float32),
#   'probabilities': array([0.80352676, 0.19647324], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2236555], dtype=float32),
#   'logistic': array([0.22729379], dtype=float32),
#   'probabilities': array([0.77270615, 0.22729379], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.02307677], dtype=float32),
#   'logistic': array([0.50576895], dtype=float32),
#   'probabilities': array([0.49423108, 0.50576895], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.00647187], dtype=float32),
#   'logistic': array([0.49838203], dtype=float32),
#   'probabilities': array([0.50161797, 0.49838206], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7598866], dtype=float32),
#   'logistic': array([0.14680454], dtype=float32),
#   'probabilities': array([0.8531955 , 0.14680454], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.44581234], dtype=float32),
#   'logistic': array([0.3903569], dtype=float32),
#   'probabilities': array([0.60964316, 0.3903569 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.75305223], dtype=float32),
#   'logistic': array([0.67984337], dtype=float32),
#   'probabilities': array([0.32015657, 0.67984337], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.23094332], dtype=float32),
#   'logistic': array([0.5574806], dtype=float32),
#   'probabilities': array([0.44251946, 0.55748063], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.3814478], dtype=float32),
#   'logistic': array([0.40577778], dtype=float32),
#   'probabilities': array([0.59422225, 0.40577778], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.17810822], dtype=float32),
#   'logistic': array([0.5444097], dtype=float32),
#   'probabilities': array([0.4555903 , 0.54440975], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2400079], dtype=float32),
#   'logistic': array([0.22443461], dtype=float32),
#   'probabilities': array([0.7755654 , 0.22443463], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3459433], dtype=float32),
#   'logistic': array([0.20653437], dtype=float32),
#   'probabilities': array([0.7934656 , 0.20653439], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8141862], dtype=float32),
#   'logistic': array([0.1401329], dtype=float32),
#   'probabilities': array([0.85986704, 0.14013295], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0392172], dtype=float32),
#   'logistic': array([0.26130107], dtype=float32),
#   'probabilities': array([0.73869896, 0.26130107], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.06540155], dtype=float32),
#   'logistic': array([0.48365545], dtype=float32),
#   'probabilities': array([0.51634455, 0.48365542], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.7086834], dtype=float32),
#   'logistic': array([0.67011017], dtype=float32),
#   'probabilities': array([0.32988983, 0.67011017], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1773773], dtype=float32),
#   'logistic': array([0.23552406], dtype=float32),
#   'probabilities': array([0.76447594, 0.23552409], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6663713], dtype=float32),
#   'logistic': array([0.15890858], dtype=float32),
#   'probabilities': array([0.84109145, 0.15890858], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
# ...
#  {'logits': array([0.8107772], dtype=float32),
#   'logistic': array([0.69227505], dtype=float32),
#   'probabilities': array([0.30772492, 0.6922751 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.50473475], dtype=float32),
#   'logistic': array([0.62357134], dtype=float32),
#   'probabilities': array([0.37642863, 0.6235714 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.81820905], dtype=float32),
#   'logistic': array([0.69385606], dtype=float32),
#   'probabilities': array([0.30614397, 0.69385606], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.23363042], dtype=float32),
#   'logistic': array([0.44185665], dtype=float32),
#   'probabilities': array([0.5581434 , 0.44185662], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.895783], dtype=float32),
#   'logistic': array([0.2899179], dtype=float32),
#   'probabilities': array([0.7100822 , 0.28991786], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.06588745], dtype=float32),
#   'logistic': array([0.5164659], dtype=float32),
#   'probabilities': array([0.4835341, 0.5164659], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5372884], dtype=float32),
#   'logistic': array([0.1769298], dtype=float32),
#   'probabilities': array([0.82307017, 0.1769298 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7488806], dtype=float32),
#   'logistic': array([0.14818844], dtype=float32),
#   'probabilities': array([0.8518116 , 0.14818844], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5089318], dtype=float32),
#   'logistic': array([0.18109715], dtype=float32),
#   'probabilities': array([0.81890285, 0.18109716], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.01930845], dtype=float32),
#   'logistic': array([0.49517304], dtype=float32),
#   'probabilities': array([0.50482696, 0.49517304], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.7597413], dtype=float32),
#   'logistic': array([0.05953884], dtype=float32),
#   'probabilities': array([0.94046116, 0.05953885], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.9535883], dtype=float32),
#   'logistic': array([0.2781638], dtype=float32),
#   'probabilities': array([0.72183627, 0.27816376], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6251667], dtype=float32),
#   'logistic': array([0.16449356], dtype=float32),
#   'probabilities': array([0.8355064 , 0.16449355], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0474938], dtype=float32),
#   'logistic': array([0.25970665], dtype=float32),
#   'probabilities': array([0.7402933 , 0.25970665], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1505383], dtype=float32),
#   'logistic': array([0.24039078], dtype=float32),
#   'probabilities': array([0.7596092 , 0.24039076], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.945865], dtype=float32),
#   'logistic': array([0.27971718], dtype=float32),
#   'probabilities': array([0.7202828 , 0.27971715], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.274157], dtype=float32),
#   'logistic': array([0.7814535], dtype=float32),
#   'probabilities': array([0.21854645, 0.7814535 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.481277], dtype=float32),
#   'logistic': array([0.18523458], dtype=float32),
#   'probabilities': array([0.8147654 , 0.18523462], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9123582], dtype=float32),
#   'logistic': array([0.12871614], dtype=float32),
#   'probabilities': array([0.8712839 , 0.12871617], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.47515333], dtype=float32),
#   'logistic': array([0.6166027], dtype=float32),
#   'probabilities': array([0.38339725, 0.6166028 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.11460161], dtype=float32),
#   'logistic': array([0.47138092], dtype=float32),
#   'probabilities': array([0.5286191 , 0.47138092], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.7287586], dtype=float32),
#   'logistic': array([0.84925354], dtype=float32),
#   'probabilities': array([0.15074643, 0.84925354], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.5566598], dtype=float32),
#   'logistic': array([0.63567936], dtype=float32),
#   'probabilities': array([0.36432067, 0.63567936], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8872805], dtype=float32),
#   'logistic': array([0.13155486], dtype=float32),
#   'probabilities': array([0.86844516, 0.13155486], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.59492874], dtype=float32),
#   'logistic': array([0.64449525], dtype=float32),
#   'probabilities': array([0.35550478, 0.64449525], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.13533449], dtype=float32),
#   'logistic': array([0.53378206], dtype=float32),
#   'probabilities': array([0.4662179 , 0.53378206], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.1805394], dtype=float32),
#   'logistic': array([0.76504475], dtype=float32),
#   'probabilities': array([0.23495522, 0.76504475], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1676557], dtype=float32),
#   'logistic': array([0.237279], dtype=float32),
#   'probabilities': array([0.762721  , 0.23727898], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5743955], dtype=float32),
#   'logistic': array([0.17159066], dtype=float32),
#   'probabilities': array([0.8284093 , 0.17159069], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.23470306], dtype=float32),
#   'logistic': array([0.5584079], dtype=float32),
#   'probabilities': array([0.44159213, 0.5584079 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.750149], dtype=float32),
#   'logistic': array([0.1480284], dtype=float32),
#   'probabilities': array([0.8519716, 0.1480284], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.3034425], dtype=float32),
#   'logistic': array([0.7864138], dtype=float32),
#   'probabilities': array([0.21358621, 0.7864138 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.12256527], dtype=float32),
#   'logistic': array([0.53060305], dtype=float32),
#   'probabilities': array([0.469397  , 0.53060305], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4923801], dtype=float32),
#   'logistic': array([0.18356475], dtype=float32),
#   'probabilities': array([0.8164353 , 0.18356475], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.3125031], dtype=float32),
#   'logistic': array([0.5774961], dtype=float32),
#   'probabilities': array([0.4225039, 0.5774961], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.10812378], dtype=float32),
#   'logistic': array([0.47299537], dtype=float32),
#   'probabilities': array([0.52700466, 0.47299537], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.1024263], dtype=float32),
#   'logistic': array([0.10886121], dtype=float32),
#   'probabilities': array([0.89113873, 0.10886122], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.05943799], dtype=float32),
#   'logistic': array([0.51485515], dtype=float32),
#   'probabilities': array([0.48514488, 0.51485515], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.3859074], dtype=float32),
#   'logistic': array([0.5952971], dtype=float32),
#   'probabilities': array([0.4047029, 0.5952971], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.0914488], dtype=float32),
#   'logistic': array([0.7486544], dtype=float32),
#   'probabilities': array([0.25134557, 0.7486544 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.5340002], dtype=float32),
#   'logistic': array([0.8225908], dtype=float32),
#   'probabilities': array([0.17740917, 0.8225908 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.31059355], dtype=float32),
#   'logistic': array([0.42296988], dtype=float32),
#   'probabilities': array([0.5770301 , 0.42296985], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6784577], dtype=float32),
#   'logistic': array([0.15729979], dtype=float32),
#   'probabilities': array([0.84270024, 0.1572998 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.330464], dtype=float32),
#   'logistic': array([0.08863119], dtype=float32),
#   'probabilities': array([0.91136885, 0.08863119], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.0594895], dtype=float32),
#   'logistic': array([0.11309703], dtype=float32),
#   'probabilities': array([0.886903  , 0.11309703], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0466933], dtype=float32),
#   'logistic': array([0.25986058], dtype=float32),
#   'probabilities': array([0.74013937, 0.25986058], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.71945596], dtype=float32),
#   'logistic': array([0.3275128], dtype=float32),
#   'probabilities': array([0.6724872, 0.3275128], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0148463], dtype=float32),
#   'logistic': array([0.2660325], dtype=float32),
#   'probabilities': array([0.73396754, 0.2660325 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)}]

# %% [markdown]
# **Interpretation**<br>
# hier haben wir auf iwelche Daten etwas vorhergesagt: BSP output
# ```
# {'logits': array([0.03003871], dtype=float32),
# 'logistic': array([0.5075091], dtype=float32),
# 'probabilities': array([0.4924909, 0.5075091], dtype=float32),
# 'class_ids': array([1], dtype=int64),
# 'classes': array([b'1'], dtype=object),
# 'all_class_ids': array([0, 1]),
# 'all_classes': array([b'0', b'1'], dtype=object)},
# ```
# Die Zeile "probabilities': array([0.4924909, 0.5075091]" gibt an das die Person zu 0.4924909 der Klasse 0 = kein Diabetis und zu 0.5075091 zu Klasse 1 = Diabetes hat

# %% [markdown]
# # DNN Klassifikator
# hier verwenden wir als direkten Vergelich zu dem bisherigen "tf.estimator.LinearClassifier" nun den "tf.estimator.DNNClassifier"

# %%
dnn_model = tf.estimator.DNNClassifier()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-276a75d2e60d> in <module>
# ----> 1 dnn_model = tf.estimator.DNNClassifier()
#
# TypeError: __init__() missing 2 required positional arguments: 'hidden_units' and 'feature_columns'

# %%
# Vergleich logistic regression
# model = tf.estimator.LinearClassifier(feature_columns=feat_cols,n_classes=2)
# hier wird ein NN aufgebaut mit 3 hidden layer zu je 10 Neuronen und 2 output-Klassen
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10],feature_columns=feat_cols,n_classes=2)

# %% [raw]
# # OH! Ein Error. Schaue dir dazu das Video an um zu lernen wieso dies geschiet und wie man es beheben kann.
# # https://github.com/tensorflow/tensorflow/blob/master/tensorflow/python/feature_column/feature_column.py
#
# dnn_model.train(input_fn=input_func,steps=1000)

# %% [markdown]
# **Lösung**<br>
# die Embeded group collum muss modifziert werden

# %%
embedded_group_column = tf.feature_column.embedding_column(assigned_group, dimension=4)

# %%
feat_cols = [num_preg ,plasma_gluc,dias_press ,tricep ,insulin,bmi,diabetes_pedigree ,embedded_group_column, age_buckets]

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train,batch_size=10,num_epochs=1000,shuffle=True)

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10],feature_columns=feat_cols,n_classes=2)

# %%
dnn_model.train(input_fn=input_func,steps=1000)

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      y=y_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
dnn_model.evaluate(eval_input_func)

# %% [markdown]
# [Vergleiche die Accuracy der logistic Regression](#Anker), mit dem DNN erreichen wir 74 % => etwas besser

# %% [markdown]
# # Gut gemacht!
