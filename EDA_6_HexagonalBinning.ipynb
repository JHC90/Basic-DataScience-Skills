# %% [markdown]
# # Hexagonal Binning

# %% [markdown]
# [TheoriCorrelation](https://github.com/JHC90/Basic-DataScience-Skills/wiki/EDA_4_ExploringData_4_Correlation)

# %%
import pandas as pd
kcData = pd.read_csv('./data/kc_house_data.csv',delimiter=',',encoding='utf-8')
kcData
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
## Create subset

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])
df.plot(kind='hexbin', x='a', y='b', gridsize=25)
print(df.head())
df['b'] = df['b'] + np.arange(1000)
df.plot(kind='hexbin', x='a', y='b', gridsize=25)
# Out:
#           a         b
# 0  2.466009 -1.403996
# 1 -0.114908 -0.019163
# 2  1.121837 -0.789577
# 3 -1.365162 -0.208325
# 4 -0.740494  1.587986

# %% [markdown]
# ## Tutorial zur Erklärung
# [link1](https://www.meccanismocomplesso.org/en/hexagonal-binning-a-new-method-of-visualization-for-data-analysis/)
#
# Wenn mehrer Variablen  in einem Scatterplot dargesellt werden, wird es schnell unübersichtlich. Mit der weiteren Variable
